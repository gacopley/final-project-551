# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import warnings
import sklearn
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ObesityFullUsedSet.csv')

# %%
df.head()
# Out:
#    Study Group Num  Study SubGroup Number  Year Period  Normal Weight  \
# 0                1                    1.1            1           41.6
# 1                1                    1.1            2           33.0
# 2                1                    1.1            3           32.3
# 3                1                    1.1            4           31.6
# 4                1                    1.1            5           30.8
#
#    Overweight  Obese
# 0        33.1   22.9
# 1        34.7   30.4
# 2        34.6   31.4
# 3        33.3   33.4
# 4        33.5   34.0

# %%
df.describe()
# Out:
#        Study Group Num  Study SubGroup Number  Year Period  Normal Weight  \
# count       160.000000             160.000000   160.000000     160.000000
# mean          3.625000               3.428063     5.500000      28.301250
# std           1.169583               1.194803     2.881299       6.671746
# min           1.000000               1.100000     1.000000      13.900000
# 25%           3.000000               3.110750     3.000000      24.275000
# 50%           4.000000               3.121500     5.500000      28.050000
# 75%           4.250000               3.714000     8.000000      32.100000
# max           5.000000               5.400000    10.000000      48.700000
#
#        Overweight       Obese
# count  160.000000  160.000000
# mean    33.371250   36.773125
# std      5.000495    7.799393
# min     23.400000   18.700000
# 25%     29.900000   32.250000
# 50%     32.800000   35.700000
# 75%     36.550000   41.150000
# max     46.300000   57.500000

# %%
df_general = df[df['Study Group Num'] < 3]

# %%
plt.figure(figsize=(10,5))
ax = df_general.corr()['Year Period'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
plt.figure(figsize=(30,10));plt.subplot(121,title = 'Correlation plot')
sns.heatmap(df_general.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation plot'}>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X = df_general.drop(columns=['Year Period'],axis=1) 
y = df_general.drop(columns=['Study Group Num', 'Study SubGroup Number', 'Normal Weight', 'Overweight', 'Obese'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=40)

# %%
lr = LogisticRegression(random_state=40)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.85
# Accuracy in Test  set   : 0.33

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)

# %%
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
train_accuracy2 = regr_1.score(X_train, y_train)
train_accuracy3 = regr_2.score(X_train, y_train)
test_accuracy2 = regr_1.score(X_test, y_test)
test_accuracy3 = regr_2.score(X_test, y_test)
print('Accuracy in depth_2 Train set   : {:.2f}'.format(train_accuracy2), 
      'Accuracy in depth_5 Train set   : {:.2f}'.format(train_accuracy3), sep='\n')
print('Accuracy in depth_2 Test  set   : {:.2f}'.format(test_accuracy2), 
      'Accuracy in depth_5 Test  set   : {:.2f}'.format(test_accuracy3), sep='\n')
# Out:
# Accuracy in depth_2 Train set   : 0.89
# Accuracy in depth_5 Train set   : 1.00
# Accuracy in depth_2 Test  set   : 0.88
# Accuracy in depth_5 Test  set   : 0.88

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
krr = KernelRidge(alpha=1.0)
krr.fit(X_train, y_train)
# Out:
# KernelRidge(alpha=1.0)

# %%
train_accuracy4 = krr.score(X_train, y_train)
test_accuracy4 = krr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy4), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy4), sep='\n')
# Out:
# Accuracy in Train set   : 0.82
# Accuracy in Test  set   : 0.89

# %%
df_race = df[df['Study Group Num'] == 3]

# %%
plt.figure(figsize=(10,5))
ax = df_race.corr()['Study SubGroup Number'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
plt.figure(figsize=(30,10));plt.subplot(121,title = 'Correlation plot')
sns.heatmap(df_race.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation plot'}>

# %%
X = df_race.drop(columns=['Year Period'],axis=1) 
y = df_race.drop(columns=['Study Group Num', 'Study SubGroup Number', 'Normal Weight', 'Overweight', 'Obese'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=40)

# %%
lr = LogisticRegression(random_state=40)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.22
# Accuracy in Test  set   : 0.00

# %%
krr = KernelRidge(alpha=1.0)
krr.fit(X_train, y_train)
# Out:
# KernelRidge(alpha=1.0)

# %%
train_accuracy4 = krr.score(X_train, y_train)
test_accuracy4 = krr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy4), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy4), sep='\n')
# Out:
# Accuracy in Train set   : 0.44
# Accuracy in Test  set   : 0.80

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)

# %%
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
train_accuracy2 = regr_1.score(X_train, y_train)
train_accuracy3 = regr_2.score(X_train, y_train)
test_accuracy2 = regr_1.score(X_test, y_test)
test_accuracy3 = regr_2.score(X_test, y_test)
print('Accuracy in depth_2 Train set   : {:.2f}'.format(train_accuracy2), 
      'Accuracy in depth_5 Train set   : {:.2f}'.format(train_accuracy3), sep='\n')
print('Accuracy in depth_2 Test  set   : {:.2f}'.format(test_accuracy2), 
      'Accuracy in depth_5 Test  set   : {:.2f}'.format(test_accuracy3), sep='\n')
# Out:
# Accuracy in depth_2 Train set   : 0.62
# Accuracy in depth_5 Train set   : 0.98
# Accuracy in depth_2 Test  set   : 0.67
# Accuracy in depth_5 Test  set   : 0.76

# %%
df_racegender = df[df['Study Group Num'] == 4]
plt.figure(figsize=(10,5))
ax = df_racegender.corr()['Study SubGroup Number'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
plt.figure(figsize=(30,10));plt.subplot(121,title = 'Correlation plot')
sns.heatmap(df_racegender.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation plot'}>

# %%
X = df_racegender.drop(columns=['Year Period'],axis=1) 
y = df_racegender.drop(columns=['Study Group Num', 'Study SubGroup Number', 'Normal Weight', 'Overweight', 'Obese'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=40)

# %%
lr = LogisticRegression(random_state=40)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.20
# Accuracy in Test  set   : 0.17

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)

# %%
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
train_accuracy2 = regr_1.score(X_train, y_train)
train_accuracy3 = regr_2.score(X_train, y_train)
test_accuracy2 = regr_1.score(X_test, y_test)
test_accuracy3 = regr_2.score(X_test, y_test)
print('Accuracy in depth_2 Train set   : {:.2f}'.format(train_accuracy2), 
      'Accuracy in depth_5 Train set   : {:.2f}'.format(train_accuracy3), sep='\n')
print('Accuracy in depth_2 Test  set   : {:.2f}'.format(test_accuracy2), 
      'Accuracy in depth_5 Test  set   : {:.2f}'.format(test_accuracy3), sep='\n')
# Out:
# Accuracy in depth_2 Train set   : 0.46
# Accuracy in depth_5 Train set   : 0.93
# Accuracy in depth_2 Test  set   : 0.23
# Accuracy in depth_5 Test  set   : 0.12

# %%
krr = KernelRidge(alpha=1.0)
krr.fit(X_train, y_train)
# Out:
# KernelRidge(alpha=1.0)

# %%
train_accuracy4 = krr.score(X_train, y_train)
test_accuracy4 = krr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy4), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy4), sep='\n')
# Out:
# Accuracy in Train set   : 0.29
# Accuracy in Test  set   : 0.64

# %%
df_money = df[df['Study Group Num'] == 5]
plt.figure(figsize=(10,5))
ax = df_money.corr()['Study SubGroup Number'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
plt.figure(figsize=(30,10));plt.subplot(121,title = 'Correlation plot')
sns.heatmap(df_money.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation plot'}>

# %%
X = df_money.drop(columns=['Year Period'],axis=1) 
y = df_money.drop(columns=['Study Group Num', 'Study SubGroup Number', 'Normal Weight', 'Overweight', 'Obese'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=40)

# %%
lr = LogisticRegression(random_state=40)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.39
# Accuracy in Test  set   : 0.25

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)

# %%
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
train_accuracy2 = regr_1.score(X_train, y_train)
train_accuracy3 = regr_2.score(X_train, y_train)
test_accuracy2 = regr_1.score(X_test, y_test)
test_accuracy3 = regr_2.score(X_test, y_test)
print('Accuracy in depth_2 Train set   : {:.2f}'.format(train_accuracy2), 
      'Accuracy in depth_5 Train set   : {:.2f}'.format(train_accuracy3), sep='\n')
print('Accuracy in depth_2 Test  set   : {:.2f}'.format(test_accuracy2), 
      'Accuracy in depth_5 Test  set   : {:.2f}'.format(test_accuracy3), sep='\n')
# Out:
# Accuracy in depth_2 Train set   : 0.73
# Accuracy in depth_5 Train set   : 0.97
# Accuracy in depth_2 Test  set   : 0.66
# Accuracy in depth_5 Test  set   : 0.73

# %%
krr = KernelRidge(alpha=1.0)
krr.fit(X_train, y_train)
# Out:
# KernelRidge(alpha=1.0)

# %%
train_accuracy4 = krr.score(X_train, y_train)
test_accuracy4 = krr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy4), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy4), sep='\n')
# Out:
# Accuracy in Train set   : 0.66
# Accuracy in Test  set   : 0.56
